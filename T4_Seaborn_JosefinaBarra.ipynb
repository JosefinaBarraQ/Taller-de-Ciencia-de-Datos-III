# %% [markdown]
#   <h1>Tarea 04: Matplotlib & Seaborn</h1>

# %% [markdown]
# <font size='4'>Completar las siguientes tareas:</font>
#
# <hr style="height:2px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# Importar las siguientes librerías: `matplotlib.pyplot, seaborn, pandas, numpy`

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## <b>Recrea la siguiente figura</b>

# %%
x = np.linspace(-4, 4, 52)

# Calcula valores para curvas
y1 = 3 * np.exp(-0.25 * x**2)
y2 = 2.8 * np.exp(-0.15 * (x - 0.1)**2)

# Configura estilo de seaborn
sns.set(style="darkgrid")

# Crea figura y ejes
fig, ax = plt.subplots()

# Curvas
sns.lineplot(x, y1, color='red', linestyle='-.', linewidth=2, label='3e^(-0.25x^2)', ax=ax)
sns.lineplot(x, y2, color='cyan', marker='o', markerfacecolor='yellow', markeredgecolor='black', markersize=6, linestyle='-', linewidth=2, label='2.8e^(-0.15(x-0.1)^2)', ax=ax)

# Etiquetas
ax.set_xlabel("That took a while", fontweight='bold')
ax.set_title('Many Plots', fontweight='bold')
ax.legend(loc='upper right')

ax2 = plt.axes([0.41, 0.18, 0.2, 0.3])
ax2.text(-1.5, 2, "Cool", color='red')
ax2.text(-0.5, 0, "Plot", color='blue')
ax2.text(1, -2, "Bro", color='green')

ax2.set_title('Small Plot')
ax2.set_xlim(-2, 2)
ax2.set_ylim(-3, 3)
ax2.set_xticks(np.arange(-2, 2.5, 1))
ax2.set_yticks(np.arange(-3, 3.5, 1))

plt.show()
# Out:
# C:\Users\JCarv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\JCarv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.

# %% [markdown]
#   <hr style="height:3px;border:none;color:#333;background-color:#333;" />
#
#  <font size='4'> Para el resto de los ejercicios se deb usar el dataset Airbnb contenido en el archivo Airbnb.xlsx.</font>
#
# <h4> <b> Lee y guarda el dataset como `abnb`</b>

# %%
abnb = pd.read_excel('Airbnb.xlsx')

# %% [markdown]
# ## <b>Revisa el head de los datos:</b>

# %%
abnb.head(5)
# Out:
#    Unnamed: 0 neighbourhood_group       neighbourhood        room_type  price  \
# 0       33941              Queens           Ridgewood  Entire home/apt    280
# 1       21257           Manhattan    Theater District     Private room    195
# 2       23462            Brooklyn            Bushwick     Private room     65
# 3       29123            Brooklyn  Bedford-Stuyvesant  Entire home/apt    126
# 4       16774           Manhattan      Hell's Kitchen  Entire home/apt    199
#
#    minimum_nights  number_of_reviews last_review
# 0               2                 40  2019-06-24
# 1               1                  9  2018-12-16
# 2               5                 20  2019-04-21
# 3               1                  9  2018-03-02
# 4              30                  4  2018-03-31

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo la tabla desaparecerá.
# Out:
#    Unnamed: 0 neighbourhood_group       neighbourhood        room_type  price  \
# 0       33941              Queens           Ridgewood  Entire home/apt    280
# 1       21257           Manhattan    Theater District     Private room    195
# 2       23462            Brooklyn            Bushwick     Private room     65
# 3       29123            Brooklyn  Bedford-Stuyvesant  Entire home/apt    126
# 4       16774           Manhattan      Hell's Kitchen  Entire home/apt    199
#
#    minimum_nights  number_of_reviews last_review
# 0               2                 40  2019-06-24
# 1               1                  9  2018-12-16
# 2               5                 20  2019-04-21
# 3               1                  9  2018-03-02
# 4              30                  4  2018-03-31

# %% [markdown]
# ## <b> Recrea el siguiente `jointplot` </b>

# %%
sns.jointplot(data=abnb, x='number_of_reviews', y='price', kind='kde', fill=True, cmap='Blues', height=5)
plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.

# %% [markdown]
# ## <b> Recrea los siguientes `boxplots` </b>

# %%
plt.figure(figsize=(8.4, 4.2))
sns.boxplot(data=abnb, x='neighbourhood_group', y='price')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Price')
plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.figure(figsize=(8.4, 4.2))

sns.set(style="ticks")
plt.figure(figsize=(12.8, 6.4))

sns.boxplot(data=abnb, x='neighbourhood_group', y='number_of_reviews', hue='room_type')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Number of Reviews')
plt.ylim(-20, 370)

plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.
# Out:
# Text(0, 0.5, 'Number of Reviews')

# %% [markdown]
# ## <b> Recrea el siguiente  `violinplot` comparando la distribución de  `Entire home/apt` y `Private room` para los 5 `neighbourhood groups`</b>

# %%
filtered_abnb = abnb.loc[abnb['room_type'].isin(['Entire home/apt', 'Private room'])]

sns.set(style="ticks")

plt.figure(figsize=(10, 6))

sns.catplot(data=filtered_abnb, x='neighbourhood_group', y='price', hue='room_type', kind='violin', split=True)


plt.xlabel('Neighbourhood Group')
plt.ylabel('Price')

plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## <b>Time Series: Recrea el siguiente gráfico</b>
#
# (Pista: Convierte la columna `last_review` a formato `DateTime`)

# %%
#No logre terminar este ejercicio, quedo muy raro
abnb['last_review'] = pd.to_datetime(abnb['last_review'])


start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2019-03-01')
abnb_timepo = abnb.loc[(abnb['last_review'] >= start_date) & (abnb['last_review'] < end_date)]

sns.set(style="ticks")


plt.figure(figsize=(10, 6))

plt.plot(abnb_timepo['last_review'], abnb_timepo['number_of_reviews'], label='Number of Reviews')
plt.plot(abnb_timepo['last_review'], abnb_timepo['price'], label='Price')

plt.xlabel('last_review')
plt.ylabel('')
plt.title('Fluctuations in Number of Reviews and Price over time')

plt.legend()
plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.
